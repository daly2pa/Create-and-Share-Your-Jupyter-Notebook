# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Kristopher Daly**
# Electrical Engineer

# %% [markdown]
# *I am interested in data science because it is going to help me in my short-term projects*

# %% [markdown]
# ### My code is supposed to make the sum of 2 + 2

# %%
2+2
# Out:
# 4

# %% [markdown]
# ***
# [www.google.com]
# ***
# - Orange Juice
# - Apple Juice
# - Coffee
# ***
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/IBM_logo.svg/1920px-IBM_logo.svg.png" alt="Alt text" title="IBM Logo" />
